# %%
import pandas as pd

# %%
data = pd.read_csv('tmpwyuGTwswimming.csv')

# %%
data
# Out:
#                                  Name                            Address  \
# 0              Aquabear AUSSI Masters  La Trobe University Sports Centre
# 1    Bairnsdale Amateur Swimming Club                                NaN
# 2              Ballarat GCO Swim Club                        PO Box 1709
# 3         Broadmeadows Swimming Clubs                         PO Box 605
# 4        Bundoora Torpedoes Swim Club                                NaN
# ..                                ...                                ...
# 248                        Splashdown                      Coppards Road
# 249                        Waterworld        Cnr Melbourne and Cox Roads
# 250   Life Activities Club Heidelberg                         PO Box 245
# 251      Ballarat YMCA Community Base                  183 Albert Street
# 252         Masters Swimming Victoria                       Sports House
#
#           Suburb  Postcode State  \
# 0       Bundoora      3083   VIC
# 1     Bairnsdale      3875   VIC
# 2       Ballarat      3354   VIC
# 3        Glenroy      3046   VIC
# 4       Bundoora      3083   VIC
# ..           ...       ...   ...
# 248  Whittington      3219   VIC
# 249      Norlane      3214   VIC
# 250      Rosanna      3084   VIC
# 251   Sebastopol      3356   VIC
# 252  Albert Park      3206   VIC
#
#                                      Business Category  \
# 0                                        Swimming Club
# 1                                        Swimming Club
# 2                                        Swimming Club
# 3                                        Swimming Club
# 4                                        Swimming Club
# ..                                                 ...
# 248  Personal training,Strength Training,Swimming Pool
# 249  Personal training,Strength Training,Swimming Pool
# 250  Recreation Group,Swimming Club,Table Tennis Cl...
# 251                     Recreation Group,Swimming Pool
# 252                           State body,Swimming Club
#
#                                 LGA                              Region
# 0        Whittlesea,Darebin,Banyule  North and West Metropolitan Region
# 1                    East Gippsland                           Gippsland
# 2                          Ballarat                           Grampians
# 3                          Moreland  North and West Metropolitan Region
# 4    Whittlesea ; Darebin ; Banyule  North and West Metropolitan Region
# ..                              ...                                 ...
# 248             Greater Geelong (C)         Barwon South Western Region
# 249             Greater Geelong (C)         Barwon South Western Region
# 250                     Banyule (C)  North and West Metropolitan Region
# 251                        Ballarat                           Grampians
# 252                Port Phillip (C)        Southern Metropolitan Region
#
# [253 rows x 8 columns]

# %% [markdown]
# ## From first record we can see that park_name `Aquabear AUSSI Masters` is classified in 3 LGA: `Whittlesea,Darebin,Banyule`.
#
# ## Let's validate this from the 'locality.csv'

# %%
locality = pd.read_csv('locality.csv')

# %%
locality
# Out:
#       LOCALITY_ID      SUBURB                 LGA  POST_CODE
# 0         1000001    Abbeyard              ALPINE       3737
# 1         1000002  Abbotsford               YARRA       3067
# 2         1000003  Aberfeldie       MOONEE VALLEY       3040
# 3         1000004   Aberfeldy             BAW BAW       3825
# 4         1000005     Acheron         MURRINDINDI       3714
# ...           ...         ...                 ...        ...
# 3216      1003217    Yulecart  SOUTHERN GRAMPIANS       3301
# 3217      1003218     Yundool               MOIRA       3727
# 3218      1003219      Yuroke                HUME       3063
# 3219      1003220     Yuulong         COLAC OTWAY       3237
# 3220      1003221     Zeerust  GREATER SHEPPARTON       3634
#
# [3221 rows x 4 columns]

# %%
locality.loc[(locality['SUBURB'] == 'Bundoora') & (locality['LGA'] == 'Whittlesea'.upper())]
# Out:
#      LOCALITY_ID    SUBURB         LGA  POST_CODE
# 426      1000427  Bundoora  WHITTLESEA       3083

# %%
locality.loc[(locality['SUBURB'] == 'Bundoora') & (locality['LGA'] == 'Darebin'.upper())]
# Out:
#      LOCALITY_ID    SUBURB      LGA  POST_CODE
# 425      1000426  Bundoora  DAREBIN       3083

# %%
locality.loc[(locality['SUBURB'] == 'Bundoora') & (locality['LGA'] == 'Banyule'.upper())]
# Out:
#      LOCALITY_ID    SUBURB      LGA  POST_CODE
# 424      1000425  Bundoora  BANYULE       3083

# %% [markdown]
# ## Indeed, Suburb 'Bundoora' is part of all the 3 LGA (Whittlesea,Darebin,Banyule)

# %% [markdown]
# ## For our database, we need this to be reflected in a long format. Hence we need to break down the LGA and make one record for each of the LGA

# %% [markdown]
# ## In order to achieve this, we need to iterate through each row of the dataframe and make records accordingly

# %% [markdown]
# ### All the Swimming clubs are not swimming pools. So we remove this business type from data

# %%
data = data[data['Business Category'] != 'Swimming Club']

# %%
selected = ['Name', 'Suburb', 'LGA', 'Address']
selected_df = data[selected]
selected_df.reset_index(drop=True,inplace=True)

# %%
# check for missing data
for idx, row in selected_df.iterrows():
    if row.isnull().values.any():
        print(idx, row)
# Out:
# 30 Name       Chewton Swimming Pool
# Suburb                   Chewton
# LGA                          NaN
# Address    Chewton Memorial Park
# Name: 30, dtype: object
# 34 Name       Coburg Outdoor Pool
# Suburb                  Coburg
# LGA                   Moreland
# Address                    NaN
# Name: 34, dtype: object
# 57 Name       Inglewood Swimming Pool
# Suburb                   Inglewood
# LGA                         Loddon
# Address                        NaN
# Name: 57, dtype: object
# 75 Name       Lismore District War Memorial Swimming Pool
# Suburb                                         Lismore
# LGA                                        Corangamite
# Address                                            NaN
# Name: 75, dtype: object
# 79 Name        Mansfield Outdoor Pool
# Suburb                   Mansfield
# LGA        Yarra Ranges , Delatite
# Address                        NaN
# Name: 79, dtype: object
# 82 Name       Mirboo North Swimming Pool
# Suburb                   Mirboo North
# LGA                   South Gippsland
# Address                           NaN
# Name: 82, dtype: object
# 87 Name       Nhill Swimming Baths
# Suburb                    Nhill
# LGA                   Hindmarsh
# Address                     NaN
# Name: 87, dtype: object
# 92 Name       Nyah Swimming Pool
# Suburb                   Nyah
# LGA                       NaN
# Address            Ouyen Road
# Name: 92, dtype: object
# 117 Name       Tallarook Swimming Pool
# Suburb                   Tallarook
# LGA                            NaN
# Address                Main Street
# Name: 117, dtype: object
# 119 Name       Terang Swimming Pool
# Suburb                   Terang
# LGA                 Corangamite
# Address                     NaN
# Name: 119, dtype: object
# 127 Name       Wodonga Olympic Pool
# Suburb                  Wodonga
# LGA               Wodonga Rural
# Address                     NaN
# Name: 127, dtype: object

# %% [markdown]
# ## There are some records that don't have LGA but Suburb. So let's check what LGA they fall into with locality.csv

# %%
locality.loc[locality['SUBURB'] == 'Knox']
# Out:
# Empty DataFrame
# Columns: [LOCALITY_ID, SUBURB, LGA, POST_CODE]
# Index: []

# %%
locality.loc[locality['SUBURB'] == 'Chewton']
# Out:
#      LOCALITY_ID   SUBURB              LGA  POST_CODE
# 586      1000587  Chewton  MOUNT ALEXANDER       3451

# %%
locality.loc[locality['SUBURB'] == 'Nyah']
# Out:
#       LOCALITY_ID SUBURB              LGA  POST_CODE
# 2176      1002177   Nyah  SWAN HILL RURAL       3594

# %%
locality.loc[locality['SUBURB'] == 'Tallarook']
# Out:
#       LOCALITY_ID     SUBURB       LGA  POST_CODE
# 2666      1002667  Tallarook  MITCHELL       3659

# %%
locality.loc[locality['SUBURB'] == 'Tallarook']['LGA'].values[0]
# Out:
# 'MITCHELL'

# %% [markdown]
# ## After research, 'Knox' is actually an LGA but not a suburb. So I believe this is a misstake by entry. Hence I will manually change it to KNOX LGA

# %% [markdown]
# ## Iterate through dataframe and change LGA accordingly

# %%
# iterrows doesn't change values from origional row unless you change values on df.copy() 
for idx, row in selected_df.iterrows():
    selected_df = selected_df.copy()
    if type(row['LGA']) == float:
        if row['Suburb'] in locality['SUBURB'].values:
            
            # if we can find this row's 'Suburb' in locality's 'SUBURB', then
            # change this row's 'LGA' to locality look up value based on the row's 'Suburb' value
            selected_df.at[idx, 'LGA'] = locality.loc[locality['SUBURB'] == row['Suburb']]['LGA'].values[0]
        
        else:
            selected_df.at[idx, 'LGA'] = row['Suburb']

# %%
# check for missing data
for idx, row in selected_df.iterrows():
    if row.isnull().values.any():
        print(idx, row)
# Out:
# 34 Name       Coburg Outdoor Pool
# Suburb                  Coburg
# LGA                   Moreland
# Address                    NaN
# Name: 34, dtype: object
# 57 Name       Inglewood Swimming Pool
# Suburb                   Inglewood
# LGA                         Loddon
# Address                        NaN
# Name: 57, dtype: object
# 75 Name       Lismore District War Memorial Swimming Pool
# Suburb                                         Lismore
# LGA                                        Corangamite
# Address                                            NaN
# Name: 75, dtype: object
# 79 Name        Mansfield Outdoor Pool
# Suburb                   Mansfield
# LGA        Yarra Ranges , Delatite
# Address                        NaN
# Name: 79, dtype: object
# 82 Name       Mirboo North Swimming Pool
# Suburb                   Mirboo North
# LGA                   South Gippsland
# Address                           NaN
# Name: 82, dtype: object
# 87 Name       Nhill Swimming Baths
# Suburb                    Nhill
# LGA                   Hindmarsh
# Address                     NaN
# Name: 87, dtype: object
# 119 Name       Terang Swimming Pool
# Suburb                   Terang
# LGA                 Corangamite
# Address                     NaN
# Name: 119, dtype: object
# 127 Name       Wodonga Olympic Pool
# Suburb                  Wodonga
# LGA               Wodonga Rural
# Address                     NaN
# Name: 127, dtype: object

# %% [markdown]
# ## After dealing with Missing values or wrong values, now we can start to fix the Multiple LGA problem

# %%
selected_df.head(25)
# Out:
#                                Name         Suburb  \
# 0            Benalla Aquatic Centre        Benalla
# 1      Diamond Valley Swimming Club   Greensbourgh
# 2            Northern Swimming Pool   Balwyn North
# 3                          Swimland  Glen Waverley
# 4            Warburton Outdoor Pool      Warburton
# 5          Apollo Bay Swimming Pool     Apollo Bay
# 6           Aquacoaster Water Slide        Mildura
# 7                         Aquastyle      Mill Park
# 8                         Aquastyle      Mill Park
# 9         Ararat Solar Olympic Pool         Ararat
# 10             Avenel Swimming Pool         Avenel
# 11              Avoca Swimming Pool          Avoca
# 12               A.B.C. Swim Centre        Rosebud
# 13       Bacchus Marsh Outdoor Pool  Bacchus Marsh
# 14          Bairnsdale Outdoor Pool     Bairnsdale
# 15              Ballan Outdoor Pool         Ballan
# 16         Beechworth Swimming Pool     Beechworth
# 17           Belgrave Swimming Pool       Belgrave
# 18          Bendigo Aquatics Centre        Bendigo
# 19   Bendigo East Solar Heated Pool        Bendigo
# 20              Bendigo Heated Pool        Bendigo
# 21         Black Hill Swimming Pool       Ballarat
# 22              Boort Swimming Pool          Boort
# 23     Brennan Park Acquatic Centre        Bendigo
# 24  Briar Hill Swimming Pool Centre     Briar Hill
#
#                              LGA                                     Address
# 0                       Delatite                               4 Mair Street
# 1   Whittlesea; Darebin; Banyule                             Flintoff Street
# 2                     Boroondara                            271 Belmore Road
# 3                         Monash                         452 Springvale Road
# 4                   Yarra Ranges                           Warburton Highway
# 5                Colac-Otway (S)                               Costin Street
# 6                  Mildura Rural                            18 Orange Avenue
# 7                     Whittlesea                           5 Mill Park Drive
# 8                     Whittlesea                     5 Development Boulevard
# 9                    Ararat (RC)                           Alexander Gardens
# 10                   Strathbogie                                Queen Street
# 11                      Pyrenees                           Rutherford Street
# 12          Mornington Peninsula                             1 Balaka Street
# 13  Wyndham , Moorabool , Melton                                Grant Street
# 14                East Gippsland                             Turnbull Street
# 15                 Moorabool (S)                              Blackwood Road
# 16                        Indigo  Beechworth Swimming Complex, Harper Avenue
# 17                  Yarra Ranges                                 Best Street
# 18               Greater Bendigo                              Barnard Street
# 19               Greater Bendigo                              Lansell Street
# 20           Greater Bendigo (C)                              12 Vine Street
# 21                      Ballarat                             Chisholm Street
# 22                        Loddon                             Lakeview Street
# 23               Greater Bendigo                         Cnr Houlahan Street
# 24             Nillumbik,Banyule              Shop 5, 111 Mountain View Road

# %%
counter = 0
for idx, row in selected_df.iterrows():
    if not row['LGA'].isalpha():
        counter+=1
        
print(counter)
# Out:
# 148

# %%
multi_lga_list = []
for idx, row in selected_df.iterrows():
    if not row['LGA'].isalpha():
        multi_lga_list.append(row['LGA'])
multi_lga_list
# Out:
# ['Whittlesea; Darebin; Banyule',
#  'Yarra Ranges',
#  'Colac-Otway (S)',
#  'Mildura Rural',
#  'Ararat (RC)',
#  'Mornington Peninsula',
#  'Wyndham , Moorabool , Melton',
#  'East Gippsland',
#  'Moorabool (S)',
#  'Yarra Ranges',
#  'Greater Bendigo',
#  'Greater Bendigo',
#  'Greater Bendigo (C)',
#  'Greater Bendigo',
#  'Nillumbik,Banyule',
#  'Boroondara (C)',
#  'Glen Eira',
#  'MOUNT ALEXANDER',
#  'Mornington Peninsula',
#  'Maroondah (C)',
#  'Greater Dandenong , Casey',
#  'Central Goldfields',
#  'Glen Eira',
#  'Greater Bendigo',
#  'South Gippsland',
#  'Macedon Ranges , Melton',
#  'Greater Bendigo',
#  'Nillumbik,Banyule',
#  'Southern Grampians',
#  'Stonnington (C); Boroondara (C)',
#  'Yarra Ranges',
#  'Yarra Ranges',
#  'Greater Bendigo',
#  'Mildura Rural',
#  'Greater Bendigo',
#  'Greater Geelong',
#  'Yarra Ranges , Knox',
#  'Cardinia , Casey',
#  'South Gippsland',
#  'Greater Shepparton , Campaspe',
#  'Macedon Ranges',
#  'Macedon Ranges',
#  'Greater Geelong (C)',
#  'Greater Geelong',
#  'Gannawarra , Campaspe',
#  'South Gippsland',
#  'Yarra Ranges',
#  'Mount Alexander',
#  'Swan Hill Rural',
#  'Yarra Ranges , Delatite',
#  'Mildura Rural',
#  'South Gippsland',
#  'Mornington Peninsula',
#  'Mornington Peninsula',
#  'Greater Dandenong',
#  'Greater Dandenong',
#  'SWAN HILL RURAL',
#  'Yarra Ranges',
#  'East Gippsland',
#  'Mornington Peninsula',
#  'Frankston (C)',
#  'Moonee Valley',
#  'Mildura Rural',
#  'Manningham (C); Maroondah (C)',
#  'Swan Hill Rural',
#  'Greater Shepparton , Campaspe',
#  'Yarra Ranges',
#  'Murrindindi , Mitchell',
#  'Pyrenees , Corangamite',
#  'Port Phillip',
#  'Port Phillip',
#  'Whittlesea,Hume',
#  'Swan Hill Rural',
#  'Central Goldfields',
#  'Wangaratta Rural',
#  'Wyndham,Melton,Brimbank',
#  'Surf Coast',
#  'Wodonga Rural',
#  'Macedon Ranges',
#  'Wangaratta Rural',
#  'Frankston (C); Casey (C)',
#  'Casey (C)',
#  'Moreland (C)',
#  'Moonee Valley (C)',
#  'Nillumbik (S); Banyule (C)',
#  'Boroondara (C)',
#  'Banyule (C)',
#  'Kingston (C); Bayside (C)',
#  'Wyndham (C)',
#  'Boroondara (C)',
#  'Yarra Ranges , Maroondah',
#  'Yarra (C)',
#  'Yarra (C)',
#  'Mildura Rural',
#  'Mornington Peninsula',
#  'Ballarat (C)',
#  'Manningham (C)',
#  'Greater Shepparton (C)',
#  'Whitehorse (C); Boroondara (C)',
#  'Moonee Valley (C); Maribyrnong (C)',
#  'Hume (C)',
#  'Moreland (C)',
#  'Melbourne (C)',
#  'Kingston (C)',
#  'Moreland (C)',
#  'Horsham (RC)',
#  'Banyule (C)',
#  'Maroondah (C); Knox (C)',
#  'Moonee Valley (C); Maribyrnong (C)',
#  'Wyndham (C); Melton (S)',
#  'Darebin (C)',
#  'Glenelg (S)',
#  'Melton (S); Hume (C)',
#  'Maribyrnong (C); Brimbank (C)',
#  'Moonee Valley (C)',
#  'Wodonga (RC)',
#  'Monash (C); Boroondara (C)',
#  'Whitehorse (C)',
#  'Warrnambool (C)',
#  'Ararat (RC)',
#  'Wyndham (C); Moorabool (S); Melton (S)',
#  'Greater Bendigo (C)',
#  'Colac-Otway (S)',
#  'Manningham (C)',
#  'Monash (C)',
#  'Mildura Rural',
#  'Frankston (C); Casey (C)',
#  'Greater Dandenong (C); Greater Dandenong (C)',
#  'Mount Alexander',
#  'Greater Dandenong (C); Casey (C)',
#  'Moonee Valley (C); Melbourne (C)',
#  'Central Goldfields (S)',
#  'Bayside (C)',
#  'Monash (C)',
#  'Monash (C)',
#  'Kingston (C); Bayside (C)',
#  'Murrindindi (S); Mitchell (S)',
#  'Brimbank (C)',
#  'Northern Grampians (S)',
#  'Manningham (C); Maroondah (C)',
#  'Wangaratta (RC)',
#  'Baw Baw (S)',
#  'Bass Coast (S)',
#  'Yarra Ranges (S)',
#  'Greater Geelong (C)',
#  'Greater Geelong (C)',
#  'Banyule (C)',
#  'Port Phillip (C)']

# %%
import re
pattern = re.compile(r'\s\W\w+\W+') # pattern for ' (C); ' or ' (C)' or ' (RC)'

# %%
re.sub(pattern, ',', 'Ararat')
# Out:
# 'Ararat'

# %%
for idx, row in selected_df.iterrows():
    selected_df = selected_df.copy()
    selected_df.at[idx, 'LGA'] = re.sub(pattern, ',', row['LGA'])

# %%
selected_df.iloc[53]
# Out:
# Name       Healesville Community Indoor Heated Pool
# Suburb                                  Healesville
# LGA                                    Yarra Ranges
# Address                               Camerons Road
# Name: 53, dtype: object

# %%
selected_df.iloc[100]
# Out:
# Name       Pyramid Hill Swimming Pool
# Suburb                   Pyramid Hill
# LGA                            Loddon
# Address               Victoria Street
# Name: 100, dtype: object

# %%
pattern = re.compile(r'\s\W\s') # pattern for ' , ' or ' ; '

# %%
for idx, row in selected_df.iterrows():
    selected_df = selected_df.copy()
    selected_df.at[idx, 'LGA'] = re.sub(pattern, ',', row['LGA'])

# %%
selected_df.head(25)
# Out:
#                                Name         Suburb  \
# 0            Benalla Aquatic Centre        Benalla
# 1      Diamond Valley Swimming Club   Greensbourgh
# 2            Northern Swimming Pool   Balwyn North
# 3                          Swimland  Glen Waverley
# 4            Warburton Outdoor Pool      Warburton
# 5          Apollo Bay Swimming Pool     Apollo Bay
# 6           Aquacoaster Water Slide        Mildura
# 7                         Aquastyle      Mill Park
# 8                         Aquastyle      Mill Park
# 9         Ararat Solar Olympic Pool         Ararat
# 10             Avenel Swimming Pool         Avenel
# 11              Avoca Swimming Pool          Avoca
# 12               A.B.C. Swim Centre        Rosebud
# 13       Bacchus Marsh Outdoor Pool  Bacchus Marsh
# 14          Bairnsdale Outdoor Pool     Bairnsdale
# 15              Ballan Outdoor Pool         Ballan
# 16         Beechworth Swimming Pool     Beechworth
# 17           Belgrave Swimming Pool       Belgrave
# 18          Bendigo Aquatics Centre        Bendigo
# 19   Bendigo East Solar Heated Pool        Bendigo
# 20              Bendigo Heated Pool        Bendigo
# 21         Black Hill Swimming Pool       Ballarat
# 22              Boort Swimming Pool          Boort
# 23     Brennan Park Acquatic Centre        Bendigo
# 24  Briar Hill Swimming Pool Centre     Briar Hill
#
#                              LGA                                     Address
# 0                       Delatite                               4 Mair Street
# 1   Whittlesea; Darebin; Banyule                             Flintoff Street
# 2                     Boroondara                            271 Belmore Road
# 3                         Monash                         452 Springvale Road
# 4                   Yarra Ranges                           Warburton Highway
# 5                   Colac-Otway,                               Costin Street
# 6                  Mildura Rural                            18 Orange Avenue
# 7                     Whittlesea                           5 Mill Park Drive
# 8                     Whittlesea                     5 Development Boulevard
# 9                        Ararat,                           Alexander Gardens
# 10                   Strathbogie                                Queen Street
# 11                      Pyrenees                           Rutherford Street
# 12          Mornington Peninsula                             1 Balaka Street
# 13      Wyndham,Moorabool,Melton                                Grant Street
# 14                East Gippsland                             Turnbull Street
# 15                    Moorabool,                              Blackwood Road
# 16                        Indigo  Beechworth Swimming Complex, Harper Avenue
# 17                  Yarra Ranges                                 Best Street
# 18               Greater Bendigo                              Barnard Street
# 19               Greater Bendigo                              Lansell Street
# 20              Greater Bendigo,                              12 Vine Street
# 21                      Ballarat                             Chisholm Street
# 22                        Loddon                             Lakeview Street
# 23               Greater Bendigo                         Cnr Houlahan Street
# 24             Nillumbik,Banyule              Shop 5, 111 Mountain View Road

# %%
pattern = re.compile(r'\W\B') # pattern for last special character like 'Knox,'

# %%
for idx, row in selected_df.iterrows():
    selected_df = selected_df.copy()
    selected_df.at[idx, 'LGA'] = re.sub(pattern, '', row['LGA'])

# %% [markdown]
# ## Now all the LGA are in this pattern: \w+,\w+
# ## Next thing is to split the multiple LGA rows and duplicate the records for each single LGA

# %%
# create a list to store idx and LGA pair
swim_lga_list = []

for idx, row in selected_df.iterrows():
    if not row['LGA'].isalpha():
        LGA_list = row['LGA'].split(',')
        temp = []
        temp.append(idx)
        temp.append(LGA_list)
        
        swim_lga_list.append(temp)

# %%
swim_lga_list
# Out:
# [[1, ['Whittlesea Darebin Banyule']],
#  [4, ['Yarra Ranges']],
#  [5, ['Colac-Otway']],
#  [6, ['Mildura Rural']],
#  [12, ['Mornington Peninsula']],
#  [13, ['Wyndham', 'Moorabool', 'Melton']],
#  [14, ['East Gippsland']],
#  [17, ['Yarra Ranges']],
#  [18, ['Greater Bendigo']],
#  [19, ['Greater Bendigo']],
#  [20, ['Greater Bendigo']],
#  [23, ['Greater Bendigo']],
#  [24, ['Nillumbik', 'Banyule']],
#  [28, ['Glen Eira']],
#  [30, ['MOUNT ALEXANDER']],
#  [36, ['Mornington Peninsula']],
#  [41, ['Greater Dandenong', 'Casey']],
#  [42, ['Central Goldfields']],
#  [43, ['Glen Eira']],
#  [45, ['Greater Bendigo']],
#  [47, ['South Gippsland']],
#  [48, ['Macedon Ranges', 'Melton']],
#  [49, ['Greater Bendigo']],
#  [50, ['Nillumbik', 'Banyule']],
#  [51, ['Southern Grampians']],
#  [52, ['Stonnington', 'Boroondara']],
#  [53, ['Yarra Ranges']],
#  [54, ['Yarra Ranges']],
#  [55, ['Greater Bendigo']],
#  [58, ['Mildura Rural']],
#  [60, ['Greater Bendigo']],
#  [61, ['Greater Geelong']],
#  [63, ['Yarra Ranges', 'Knox']],
#  [64, ['Cardinia', 'Casey']],
#  [65, ['South Gippsland']],
#  [66, ['Greater Shepparton', 'Campaspe']],
#  [67, ['Macedon Ranges']],
#  [68, ['Macedon Ranges']],
#  [69, ['Greater Geelong']],
#  [70, ['Greater Geelong']],
#  [72, ['Gannawarra', 'Campaspe']],
#  [73, ['South Gippsland']],
#  [74, ['Yarra Ranges']],
#  [77, ['Mount Alexander']],
#  [78, ['Swan Hill Rural']],
#  [79, ['Yarra Ranges', 'Delatite']],
#  [80, ['Mildura Rural']],
#  [82, ['South Gippsland']],
#  [83, ['Mornington Peninsula']],
#  [85, ['Mornington Peninsula']],
#  [88, ['Greater Dandenong']],
#  [89, ['Greater Dandenong']],
#  [92, ['SWAN HILL RURAL']],
#  [94, ['Yarra Ranges']],
#  [95, ['East Gippsland']],
#  [98, ['Mornington Peninsula']],
#  [101, ['Moonee Valley']],
#  [102, ['Mildura Rural']],
#  [104, ['Manningham', 'Maroondah']],
#  [105, ['Swan Hill Rural']],
#  [107, ['Greater Shepparton', 'Campaspe']],
#  [109, ['Yarra Ranges']],
#  [110, ['Murrindindi', 'Mitchell']],
#  [111, ['Pyrenees', 'Corangamite']],
#  [112, ['Port Phillip']],
#  [113, ['Port Phillip']],
#  [114, ['Whittlesea', 'Hume']],
#  [115, ['Swan Hill Rural']],
#  [116, ['Central Goldfields']],
#  [122, ['Wangaratta Rural']],
#  [125, ['Wyndham', 'Melton', 'Brimbank']],
#  [126, ['Surf Coast']],
#  [127, ['Wodonga Rural']],
#  [128, ['Macedon Ranges']],
#  [131, ['Wangaratta Rural']],
#  [132, ['Frankston', 'Casey']],
#  [136, ['Moonee Valley']],
#  [137, ['Nillumbik', 'Banyule']],
#  [140, ['Kingston', 'Bayside']],
#  [143, ['Yarra Ranges', 'Maroondah']],
#  [146, ['Mildura Rural']],
#  [148, ['Mornington Peninsula']],
#  [151, ['Greater Shepparton']],
#  [152, ['Whitehorse', 'Boroondara']],
#  [153, ['Moonee Valley', 'Maribyrnong']],
#  [161, ['Maroondah', 'Knox']],
#  [162, ['Moonee Valley', 'Maribyrnong']],
#  [163, ['Wyndham', 'Melton']],
#  [166, ['Melton', 'Hume']],
#  [167, ['Maribyrnong', 'Brimbank']],
#  [168, ['Moonee Valley']],
#  [170, ['Monash', 'Boroondara']],
#  [174, ['Wyndham', 'Moorabool', 'Melton']],
#  [175, ['Greater Bendigo']],
#  [176, ['Colac-Otway']],
#  [179, ['Mildura Rural']],
#  [180, ['Frankston', 'Casey']],
#  [181, ['Greater Dandenong', 'Greater Dandenong']],
#  [182, ['Mount Alexander']],
#  [183, ['Greater Dandenong', 'Casey']],
#  [184, ['Moonee Valley', 'Melbourne']],
#  [185, ['Central Goldfields']],
#  [190, ['Kingston', 'Bayside']],
#  [191, ['Murrindindi', 'Mitchell']],
#  [193, ['Northern Grampians']],
#  [194, ['Manningham', 'Maroondah']],
#  [196, ['Baw Baw']],
#  [198, ['Bass Coast']],
#  [199, ['Yarra Ranges']],
#  [200, ['Greater Geelong']],
#  [201, ['Greater Geelong']],
#  [204, ['Port Phillip']]]

# %%
# false_pairs are something like [25, ['Port Phillip']] where the second element in the list returns False when tested with
# str.isalpha() but actually it is a one-element-list. The reason that caused this is that this element has a white space in
# its string
false_pairs = []
for pairs in swim_lga_list:
    if len(pairs[1]) == 1:
        false_pairs.append(pairs)

# %%
false_pairs
# Out:
# [[1, ['Whittlesea Darebin Banyule']],
#  [4, ['Yarra Ranges']],
#  [5, ['Colac-Otway']],
#  [6, ['Mildura Rural']],
#  [12, ['Mornington Peninsula']],
#  [14, ['East Gippsland']],
#  [17, ['Yarra Ranges']],
#  [18, ['Greater Bendigo']],
#  [19, ['Greater Bendigo']],
#  [20, ['Greater Bendigo']],
#  [23, ['Greater Bendigo']],
#  [28, ['Glen Eira']],
#  [30, ['MOUNT ALEXANDER']],
#  [36, ['Mornington Peninsula']],
#  [42, ['Central Goldfields']],
#  [43, ['Glen Eira']],
#  [45, ['Greater Bendigo']],
#  [47, ['South Gippsland']],
#  [49, ['Greater Bendigo']],
#  [51, ['Southern Grampians']],
#  [53, ['Yarra Ranges']],
#  [54, ['Yarra Ranges']],
#  [55, ['Greater Bendigo']],
#  [58, ['Mildura Rural']],
#  [60, ['Greater Bendigo']],
#  [61, ['Greater Geelong']],
#  [65, ['South Gippsland']],
#  [67, ['Macedon Ranges']],
#  [68, ['Macedon Ranges']],
#  [69, ['Greater Geelong']],
#  [70, ['Greater Geelong']],
#  [73, ['South Gippsland']],
#  [74, ['Yarra Ranges']],
#  [77, ['Mount Alexander']],
#  [78, ['Swan Hill Rural']],
#  [80, ['Mildura Rural']],
#  [82, ['South Gippsland']],
#  [83, ['Mornington Peninsula']],
#  [85, ['Mornington Peninsula']],
#  [88, ['Greater Dandenong']],
#  [89, ['Greater Dandenong']],
#  [92, ['SWAN HILL RURAL']],
#  [94, ['Yarra Ranges']],
#  [95, ['East Gippsland']],
#  [98, ['Mornington Peninsula']],
#  [101, ['Moonee Valley']],
#  [102, ['Mildura Rural']],
#  [105, ['Swan Hill Rural']],
#  [109, ['Yarra Ranges']],
#  [112, ['Port Phillip']],
#  [113, ['Port Phillip']],
#  [115, ['Swan Hill Rural']],
#  [116, ['Central Goldfields']],
#  [122, ['Wangaratta Rural']],
#  [126, ['Surf Coast']],
#  [127, ['Wodonga Rural']],
#  [128, ['Macedon Ranges']],
#  [131, ['Wangaratta Rural']],
#  [136, ['Moonee Valley']],
#  [146, ['Mildura Rural']],
#  [148, ['Mornington Peninsula']],
#  [151, ['Greater Shepparton']],
#  [168, ['Moonee Valley']],
#  [175, ['Greater Bendigo']],
#  [176, ['Colac-Otway']],
#  [179, ['Mildura Rural']],
#  [182, ['Mount Alexander']],
#  [185, ['Central Goldfields']],
#  [193, ['Northern Grampians']],
#  [196, ['Baw Baw']],
#  [198, ['Bass Coast']],
#  [199, ['Yarra Ranges']],
#  [200, ['Greater Geelong']],
#  [201, ['Greater Geelong']],
#  [204, ['Port Phillip']]]

# %% [markdown]
# ## [49, ['Whittlesea Darebin Banyule']]
#
# ## This record is actually not an LGA. It's actually 3 LGA but deliminated by single space

# %%
for pairs in false_pairs:
    
    swim_lga_list.remove(pairs)

# %%
swim_lga_list.append([1, 'Whittlesea Darebin Banyule'.split()])

# %%
swim_lga_list
# Out:
# [[13, ['Wyndham', 'Moorabool', 'Melton']],
#  [24, ['Nillumbik', 'Banyule']],
#  [41, ['Greater Dandenong', 'Casey']],
#  [48, ['Macedon Ranges', 'Melton']],
#  [50, ['Nillumbik', 'Banyule']],
#  [52, ['Stonnington', 'Boroondara']],
#  [63, ['Yarra Ranges', 'Knox']],
#  [64, ['Cardinia', 'Casey']],
#  [66, ['Greater Shepparton', 'Campaspe']],
#  [72, ['Gannawarra', 'Campaspe']],
#  [79, ['Yarra Ranges', 'Delatite']],
#  [104, ['Manningham', 'Maroondah']],
#  [107, ['Greater Shepparton', 'Campaspe']],
#  [110, ['Murrindindi', 'Mitchell']],
#  [111, ['Pyrenees', 'Corangamite']],
#  [114, ['Whittlesea', 'Hume']],
#  [125, ['Wyndham', 'Melton', 'Brimbank']],
#  [132, ['Frankston', 'Casey']],
#  [137, ['Nillumbik', 'Banyule']],
#  [140, ['Kingston', 'Bayside']],
#  [143, ['Yarra Ranges', 'Maroondah']],
#  [152, ['Whitehorse', 'Boroondara']],
#  [153, ['Moonee Valley', 'Maribyrnong']],
#  [161, ['Maroondah', 'Knox']],
#  [162, ['Moonee Valley', 'Maribyrnong']],
#  [163, ['Wyndham', 'Melton']],
#  [166, ['Melton', 'Hume']],
#  [167, ['Maribyrnong', 'Brimbank']],
#  [170, ['Monash', 'Boroondara']],
#  [174, ['Wyndham', 'Moorabool', 'Melton']],
#  [180, ['Frankston', 'Casey']],
#  [181, ['Greater Dandenong', 'Greater Dandenong']],
#  [183, ['Greater Dandenong', 'Casey']],
#  [184, ['Moonee Valley', 'Melbourne']],
#  [190, ['Kingston', 'Bayside']],
#  [191, ['Murrindindi', 'Mitchell']],
#  [194, ['Manningham', 'Maroondah']],
#  [1, ['Whittlesea', 'Darebin', 'Banyule']]]

# %% [markdown]
# ## Make a new dataframe to duplicate the records for each LGA

# %%
duplicate_LGA = pd.DataFrame(columns=['Name', 'Suburb', 'LGA', 'Address'])

# %%
name_list = []
suburb_list = []
lga_list = []
address_list = []
for pairs in swim_lga_list:
    for lga in pairs[1]:
        lga_list.append(lga)
        
        # store data in a temporary variable then append it to corresponding list 
        name = selected_df.iloc[pairs[0]]['Name']
        suburb = selected_df.iloc[pairs[0]]['Suburb']
        address = selected_df.iloc[pairs[0]]['Address']
        
        suburb_list.append(suburb)
        name_list.append(name)
        address_list.append(address)

# %%
duplicate_LGA['Name'] = name_list
duplicate_LGA['Suburb'] = suburb_list
duplicate_LGA['LGA'] = lga_list
duplicate_LGA['Address'] = address_list

# %%
duplicate_LGA
# Out:
#                                Name         Suburb         LGA  \
# 0        Bacchus Marsh Outdoor Pool  Bacchus Marsh     Wyndham
# 1        Bacchus Marsh Outdoor Pool  Bacchus Marsh   Moorabool
# 2        Bacchus Marsh Outdoor Pool  Bacchus Marsh      Melton
# 3   Briar Hill Swimming Pool Centre     Briar Hill   Nillumbik
# 4   Briar Hill Swimming Pool Centre     Briar Hill     Banyule
# ..                              ...            ...         ...
# 75          Vicki Field Swim School       Ringwood  Manningham
# 76          Vicki Field Swim School       Ringwood   Maroondah
# 77     Diamond Valley Swimming Club   Greensbourgh  Whittlesea
# 78     Diamond Valley Swimming Club   Greensbourgh     Darebin
# 79     Diamond Valley Swimming Club   Greensbourgh     Banyule
#
#                            Address
# 0                     Grant Street
# 1                     Grant Street
# 2                     Grant Street
# 3   Shop 5, 111 Mountain View Road
# 4   Shop 5, 111 Mountain View Road
# ..                             ...
# 75                  108 New Street
# 76                  108 New Street
# 77                 Flintoff Street
# 78                 Flintoff Street
# 79                 Flintoff Street
#
# [80 rows x 4 columns]

# %%
for pairs in swim_lga_list:
    
    selected_df.drop(pairs[0],inplace=True)

# %%
selected_df
# Out:
#                                 Name         Suburb              LGA  \
# 0             Benalla Aquatic Centre        Benalla         Delatite
# 2             Northern Swimming Pool   Balwyn North       Boroondara
# 3                           Swimland  Glen Waverley           Monash
# 4             Warburton Outdoor Pool      Warburton     Yarra Ranges
# 5           Apollo Bay Swimming Pool     Apollo Bay      Colac-Otway
# ..                               ...            ...              ...
# 200                       Splashdown    Whittington  Greater Geelong
# 201                       Waterworld        Norlane  Greater Geelong
# 202  Life Activities Club Heidelberg        Rosanna          Banyule
# 203     Ballarat YMCA Community Base     Sebastopol         Ballarat
# 204        Masters Swimming Victoria    Albert Park     Port Phillip
#
#                          Address
# 0                  4 Mair Street
# 2               271 Belmore Road
# 3            452 Springvale Road
# 4              Warburton Highway
# 5                  Costin Street
# ..                           ...
# 200                Coppards Road
# 201  Cnr Melbourne and Cox Roads
# 202                   PO Box 245
# 203            183 Albert Street
# 204                 Sports House
#
# [167 rows x 4 columns]

# %%
swimming_pool = pd.concat([selected_df, duplicate_LGA])

# %%
swimming_pool
# Out:
#                             Name         Suburb           LGA  \
# 0         Benalla Aquatic Centre        Benalla      Delatite
# 2         Northern Swimming Pool   Balwyn North    Boroondara
# 3                       Swimland  Glen Waverley        Monash
# 4         Warburton Outdoor Pool      Warburton  Yarra Ranges
# 5       Apollo Bay Swimming Pool     Apollo Bay   Colac-Otway
# ..                           ...            ...           ...
# 75       Vicki Field Swim School       Ringwood    Manningham
# 76       Vicki Field Swim School       Ringwood     Maroondah
# 77  Diamond Valley Swimming Club   Greensbourgh    Whittlesea
# 78  Diamond Valley Swimming Club   Greensbourgh       Darebin
# 79  Diamond Valley Swimming Club   Greensbourgh       Banyule
#
#                 Address
# 0         4 Mair Street
# 2      271 Belmore Road
# 3   452 Springvale Road
# 4     Warburton Highway
# 5         Costin Street
# ..                  ...
# 75       108 New Street
# 76       108 New Street
# 77      Flintoff Street
# 78      Flintoff Street
# 79      Flintoff Street
#
# [247 rows x 4 columns]

# %%
swimming_pool['LGA'] = swimming_pool['LGA'].apply(lambda x: x.upper())

# %%
locality = pd.read_csv('locality.csv')

# %%
locality_lga = locality['LGA'].sort_values().unique()
swimming_lga = swimming_pool['LGA'].sort_values().unique()

# %%
locality_difference = set(swimming_lga) - set(locality_lga)

# %%
locality_difference
# Out:
# {'ARARAT',
#  'COLAC-OTWAY',
#  'DELATITE',
#  'HORSHAM',
#  'MORNINGTON PENINSULA',
#  'WANGARATTA',
#  'WODONGA RURAL'}

# %% [markdown]
# ## CHEWTON is actually a suburb of MOUNT ALEXANDER (LGA), NYAH is a suburb of SWAN HILL RURAL, TALLAROOK is a suburb of MITCHELL

# %% [markdown]
# ## ARARAT, COLAC-OTWAY, DELATITE, HORSHAM, LA TROBE, WANGARATTA, are LGA that locality doesn't have. But after examination, I found that these are either different naming convention or old LGA that now belong to another LGA

# %%
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'MORNINGTON PENINSULA', 'MORNINGTON', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'CHEWTON', 'MOUNT ALEXANDER', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'WODONGA RURAL', 'WODONGA', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'NYAH', 'SWAN HILL RURAL', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'TALLAROOK', 'MITCHELL', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'ARARAT', 'ARARAT RURAL', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'COLAC-OTWAY', 'COLAC OTWAY', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'DELATITE', 'MANSFIELD', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'HORSHAM', 'HORSHAM RURAL', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'LA TROBE', 'LATROBE', inplace = True)
swimming_pool['LGA'].mask(swimming_pool['LGA'] == 'WANGARATTA', 'WANGARATTA RURAL', inplace = True)

# %%
final_sp = pd.DataFrame({'LGA': swimming_pool['LGA'],
                        'PARK_NAME' : swimming_pool['Name'],
                        'CATEGORY' : 'Swimming pool',
                        'ADDRESS' : swimming_pool['Address']})

# %%
final_sp.drop_duplicates(keep='first', inplace=True)

# %%
final_sp.to_csv('swimming pool final.csv', index=False)
